# %%
import geopandas as gpd
import folium
import mapclassify
from matplotlib import pyplot as plt

# %%
#file type must be .shp
file = gpd.read_file('nga_admin_boundaries.shp/nga_admin2.shp')
print(file.columns)
# Out:
# Index(['adm2_name', 'adm2_name1', 'adm2_name2', 'adm2_name3', 'adm2_pcode',
#        'adm1_name', 'adm1_name1', 'adm1_name2', 'adm1_name3', 'adm1_pcode',
#        'adm0_name', 'adm0_name1', 'adm0_name2', 'adm0_name3', 'adm0_pcode',
#        'valid_on', 'valid_to', 'area_sqkm', 'version', 'lang', 'lang1',
#        'lang2', 'lang3', 'adm2_ref_n', 'sendist_en', 'sendistpco',
#        'center_lat', 'center_lon', 'geometry'],
#       dtype='str')

# %%
file.head()
# Out:
#    adm2_name adm2_name1 adm2_name2 adm2_name3 adm2_pcode  \
# 0  Aba North       None       None       None   NG001001
# 1  Aba South       None       None       None   NG001002
# 2     Abadam       None       None       None   NG008001
# 3      Abaji       None       None       None   NG015001
# 4       Abak       None       None       None   NG003001
#
#                    adm1_name adm1_name1 adm1_name2 adm1_name3 adm1_pcode  ...  \
# 0                       Abia       None       None       None      NG001  ...
# 1                       Abia       None       None       None      NG001  ...
# 2                      Borno       None       None       None      NG008  ...
# 3  Federal Capital Territory       None       None       None      NG015  ...
# 4                  Akwa Ibom       None       None       None      NG003  ...
#
#   lang lang1 lang2 lang3 adm2_ref_n                 sendist_en sendistpco  \
# 0   en  None  None  None  Aba North                 Abia South    NG00103
# 1   en  None  None  None  Aba South                 Abia South    NG00103
# 2   en  None  None  None     Abadam                Borno North    NG00802
# 3   en  None  None  None      Abaji  Federal Capital Territory    NG01501
# 4   en  None  None  None       Abak       Akwa Ibom North West    NG00302
#
#    center_lat center_lon                                           geometry
# 0    5.108285   7.342101  POLYGON ((7.40111 5.08195, 7.40013 5.08237, 7....
# 1    5.084251   7.349092  POLYGON ((7.38749 5.08275, 7.38632 5.08236, 7....
# 2   13.394776  13.274466  POLYGON ((13.83477 13.42336, 13.81909 13.42175...
# 3    8.839609   6.818541  POLYGON ((7.04587 9.2305, 7.02654 9.22216, 7.0...
# 4    5.004405   7.798940  POLYGON ((7.81124 5.09453, 7.81233 5.09367, 7....
#
# [5 rows x 29 columns]

# %%
list_cols = file.columns

# %%
print(file.columns)
# Out:
# Index(['adm1_name', 'adm1_name1', 'adm1_name2', 'adm1_name3', 'adm1_pcode',
#        'adm0_name', 'adm0_name1', 'adm0_name2', 'adm0_name3', 'adm0_pcode',
#        'valid_on', 'valid_to', 'area_sqkm', 'version', 'lang', 'lang1',
#        'lang2', 'lang3', 'adm1_ref_n', 'center_lat', 'center_lon', 'geometry'],
#       dtype='str')

# %%
m = file.explore('adm1_name',tooltip=False, popup=['adm2_name','adm1_name', 'area_sqkm','adm2_ref_n','sendist_en','center_lat','center_lon'])
m.save("map.html")

# %%
import webbrowser
webbrowser.open("map.html")
# Out:
# True
